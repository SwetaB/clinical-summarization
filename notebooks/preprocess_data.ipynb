# %%
import pandas as pd
import os 
import glob2

# %%
# Subset data for clinical notes not longer than 1500 words
'''
df_raw = pd.read_csv("../data/raw/PMC-Patients.csv")
df_raw.dropna(inplace=True)
df_raw['row_len'] = df_raw['patient'].apply(lambda x: len(str(x)))
df_subset = df_raw[df_raw['row_len']< 1500]
print(df_subset.shape)
df_subset.to_csv("../data/raw/PMC-Patients-Subset-ls1500.csv", index=False)
'''
# Out:
# (35235, 11)

# %%
df_raw = pd.read_csv("../data/raw/PMC-Patients.csv")
summary_df = pd.read_csv("../data/summaries/structured_summaries_20250425_202927_checkpoint_16500.csv")

# %%
summary_df
# Out:
#        patient_id                                               case  \
# 0          123368  A 41-year-old male presented with progressivel...
# 1          110688  A 40-year old male presented to the urology ou...
# 2            4196  A 48-year-old premenopausal woman was referred...
# 3           79394  Case 1 is a 63-year-old woman whose smoking in...
# 4           27902  Patient 1: 26-year-old right-handed male with ...
# ...           ...                                                ...
# 16495      105412  An 86-year-old Japanese man was referred to us...
# 16496       14665  A 20-year-old female automobile driver was inj...
# 16497       69857  A 28-year-old male presented at the outpatient...
# 16498         344  A 31-year-old man categorized as New York Hear...
# 16499       66358  A 29-year-old female presented with a left pro...
#
#                                       structured_summary
# 0      History: Patient had a history of impaired glu...
# 1      History: Patient underwent transurethral resec...
# 2      History: Hysterectomy for uterine leiomyoma 13...
# 3      History: Patient is a 63-year-old woman with a...
# 4      History: Left transradial amputation in 2007\n...
# ...                                                  ...
# 16495  History: None provided\n\nAn 86-year-old Japan...
# 16496  History: None provided\n\nA 20-year-old female...
# 16497  History: Patient has a history of repeated ins...
# 16498  History: Patient had a history of surgery for ...
# 16499  History: Patient with a history of hyperthyroi...
#
# [16500 rows x 3 columns]
